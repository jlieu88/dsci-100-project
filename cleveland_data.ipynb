# %%
library(tidyverse)
library(repr)
library(tidymodels)

# %%
colnames <- c("index", "age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", 
              "slope", "ca", "thal", "num")

cleveland <- read_csv("data/cleveland.csv", col_names = colnames, , skip = 1)
switzerland <- read_csv("data/switzerland.csv", col_names = colnames, , skip = 1)
va <- read_csv("data/va_longbeach.csv", col_names = colnames, , skip = 1)
hungary <- read_csv("data/hungary.csv", col_name = colnames, skip = 1)



hungary

cp_vs_age <- ggplot(cleveland, aes(x = age, y = chol, color = as_factor(num))) +
             geom_point() +
             xlab("Age") +
             ylab("Chol") +
             ggtitle("Age vs Chol")
cp_vs_age

cp_vs_trestbps <- ggplot(cleveland, aes(x = age, y = trestbps, color = as_factor(num))) +
             geom_point() +
             xlab("Age") +
             ylab("Trestbps") +
             ggtitle("Age vs Trestbps")
cp_vs_trestbps

cp_vs_thelach <- ggplot(cleveland, aes(x = age, y = thalach, color = as_factor(num))) +
             geom_point() +
             xlab("Age") +
             ylab("Thalach") +
             ggtitle("Age vs Thalach")
cp_vs_thelach

cp_vs_oldpeak <- ggplot(cleveland, aes(x = age, y = oldpeak, color = as_factor(num))) +
             geom_point() +
             xlab("Age") +
             ylab("Oldpeak") +
             ggtitle("Age vs Oldpeak")
cp_vs_oldpeak
# Out:
# Rows: 303 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): ca, thal
# dbl (13): index, age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang,...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 123 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): trestbps, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal
# dbl (6): index, age, sex, cp, chol, num
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 200 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): trestbps, chol, fbs, thalach, exang, oldpeak, slope, ca, thal
# ...
