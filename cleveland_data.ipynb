# %%
library(tidyverse)
library(repr)
library(tidymodels)

# %%
colnames1 <- c("index", "age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", 
              "slope", "ca", "thal", "num")

colnames2 <- c("age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", 
              "slope", "ca", "thal", "num")
cleveland_raw <- read_csv("data/cleveland.csv", col_name = colnames1, , skip = 1)
switzerland_raw <- read_csv("data/switzerland.csv", col_name = colnames1, , skip = 1)
va_raw <- read_csv("data/va_longbeach.csv", col_name = colnames1, , skip = 1)
hungary <- read_csv("data/hungary.csv", col_name = colnames2, skip = 1)

cleveland <- select(cleveland_raw, -index)
switzerland <- select(switzerland_raw, -index)
va <- select(va_raw, -index)



database_raw <- rbind(cleveland, switzerland, va, hungary)
database <- database_raw |>
            filter(age != "?") |>
            filter(sex != "?") |>
            filter(cp != "?") |>
            filter(trestbps != "?") |>
            filter(chol != "?") |>
            filter(fbs != "?") |>
            filter(restecg != "?") |>
            filter(thalach != "?") |>
            filter(exang != "?") |>
            filter(oldpeak != "?") |>
            filter(slope != "?") |>
            filter(ca != "?") |>
            filter(thal != "?") |>
            filter(num != "?") |>
            filter(exang != -9) |>
            filter(fbs != -9) |>
            filter(slope != -9) |>
            filter(ca != -9) |>
            filter(ca != 9)
database

# Totally, there are 5 data frames:
# 1. cleveland
# 2. switzerland
# 3. va
# 4. hungary
# 5. database






# age_vs_oldpeak <- ggplot(database, aes(x = age, y = oldpeak, color = as_factor(sex))) +
#              geom_point() +
#              xlab("Age") +
#              ylab("Oldpeak") +
#              ggtitle("Age vs Oldpeak")
# age_vs_oldpeak

# age_vs_trestbps <- ggplot(database, aes(x = age, y = trestbps, color = as_factor(sex))) +
#              geom_point() +
#              xlab("Age") +
#              ylab("trestbps") +
#              ggtitle("Age vs trestbps")
# age_vs_trestbps


# age_vs_thalach <- ggplot(database, aes(x = age, y = thalach, color = as_factor(sex))) +
#              geom_point() +
#              xlab("Age") +
#              ylab("thalach") +
#              ggtitle("Age vs thalach")
# age_vs_thalach


# age_vs_trestbps <- ggplot(database, aes(x = age, y = trestbps, color = as_factor(sex))) +
#              geom_point() +
#              xlab("Age") +
#              ylab("trestbps") +
#              ggtitle("Age vs trestbps")
          
# age_vs_trestbps

# age_vs_chol <- ggplot(database, aes(x = age, y = chol, color = as_factor(sex))) +
#              geom_point() +
#              xlab("Age") +
#              ylab("chol") +
#              ggtitle("Age vs chol")
          
# age_vs_chol



# thalach_vs_trestbps <- ggplot(database, aes(x = thalach, y = trestbps, color = as_factor(exang))) +
#              geom_point() +
#              xlab("thalach") +
#              ylab("trestbps") +
#              ggtitle("thalach vs trestbps")
# thalach_vs_trestbps
# Out:
# Rows: 303 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): ca, thal
# dbl (13): index, age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang,...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 123 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): trestbps, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal
# dbl (6): index, age, sex, cp, chol, num
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 200 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): trestbps, chol, fbs, thalach, exang, oldpeak, slope, ca, thal
# dbl (6): index, age, sex, cp, restecg, num
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 294 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (14): age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpea...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     age sex cp trestbps chol fbs restecg thalach exang oldpeak slope ca  thal
# 1   63  1   1  145      233  1   2       150     0     2.3     3     0.0 6.0
# 2   67  1   4  160      286  0   2       108     1     1.5     2     3.0 3.0
# 3   67  1   4  120      229  0   2       129     1     2.6     2     2.0 7.0
# 4   37  1   3  130      250  0   0       187     0     3.5     3     0.0 3.0
# 5   41  0   2  130      204  0   2       172     0     1.4     1     0.0 3.0
# 6   56  1   2  120      236  0   0       178     0     0.8     1     0.0 3.0
# 7   62  0   4  140      268  0   2       160     0     3.6     3     2.0 3.0
# 8   57  0   4  120      354  0   0       163     1     0.6     1     0.0 3.0
# 9   63  1   4  130      254  0   2       147     0     1.4     2     1.0 7.0
# 10  53  1   4  140      203  1   2       155     1     3.1     3     0.0 7.0
# 11  57  1   4  140      192  0   0       148     0     0.4     2     0.0 6.0
# 12  56  0   2  140      294  0   2       153     0     1.3     2     0.0 3.0
# 13  56  1   3  130      256  1   2       142     1     0.6     2     1.0 6.0
# 14  44  1   2  120      263  0   0       173     0     0       1     0.0 7.0
# 15  52  1   3  172      199  1   0       162     0     0.5     1     0.0 7.0
# 16  57  1   3  150      168  0   0       174     0     1.6     1     0.0 3.0
# 17  48  1   2  110      229  0   0       168     0     1       3     0.0 7.0
# 18  54  1   4  140      239  0   0       160     0     1.2     1     0.0 3.0
# 19  48  0   3  130      275  0   0       139     0     0.2     1     0.0 3.0
# 20  49  1   2  130      266  0   0       171     0     0.6     1     0.0 3.0
# 21  64  1   1  110      211  0   2       144     1     1.8     2     0.0 3.0
# 22  58  0   1  150      283  1   2       162     0     1       1     0.0 3.0
# 23  58  1   2  120      284  0   2       160     0     1.8     2     0.0 3.0
# 24  58  1   3  132      224  0   2       173     0     3.2     1     2.0 7.0
# 25  60  1   4  130      206  0   2       132     1     2.4     2     2.0 7.0
# 26  50  0   3  120      219  0   0       158     0     1.6     2     0.0 3.0
# 27  58  0   3  120      340  0   0       172     0     0       1     0.0 3.0
# 28  66  0   1  150      226  0   0       114     0     2.6     3     0.0 3.0
# 29  43  1   4  150      247  0   0       171     0     1.5     1     0.0 3.0
# 30  40  1   4  110      167  0   2       114     1     2       2     0.0 7.0
# ⋮   ⋮   ⋮   ⋮  ⋮        ⋮    ⋮   ⋮       ⋮       ⋮     ⋮       ⋮     ⋮   ⋮
# 270 71  0   4  112      149  0   0       125     0     1.6     2     0.0 3.0
# 271 59  1   1  134      204  0   0       162     0     0.8     1     2.0 3.0
# 272 64  1   1  170      227  0   2       155     0     0.6     2     0.0 7.0
# 273 66  0   3  146      278  0   2       152     0     0       2     1.0 3.0
# 274 39  0   3  138      220  0   0       152     0     0       2     0.0 3.0
# 275 57  1   2  154      232  0   2       164     0     0       1     1.0 3.0
# 276 58  0   4  130      197  0   0       131     0     0.6     2     0.0 3.0
# 277 57  1   4  110      335  0   0       143     1     3       2     1.0 7.0
# 278 47  1   3  130      253  0   0       179     0     0       1     0.0 3.0
# 279 55  0   4  128      205  0   1       130     1     2       2     1.0 7.0
# 280 35  1   2  122      192  0   0       174     0     0       1     0.0 3.0
# 281 61  1   4  148      203  0   0       161     0     0       1     1.0 7.0
# 282 58  1   4  114      318  0   1       140     0     4.4     3     3.0 6.0
# 283 58  0   4  170      225  1   2       146     1     2.8     2     2.0 6.0
# 284 56  1   2  130      221  0   2       163     0     0       1     0.0 7.0
# 285 56  1   2  120      240  0   0       169     0     0       3     0.0 3.0
# 286 67  1   3  152      212  0   2       150     0     0.8     2     0.0 7.0
# 287 55  0   2  132      342  0   0       166     0     1.2     1     0.0 3.0
# 288 44  1   4  120      169  0   0       144     1     2.8     3     0.0 6.0
# 289 63  1   4  140      187  0   2       144     1     4       1     2.0 7.0
# 290 63  0   4  124      197  0   0       136     1     0       2     0.0 3.0
# 291 41  1   2  120      157  0   0       182     0     0       1     0.0 3.0
# 292 59  1   4  164      176  1   2       90      0     1       2     2.0 6.0
# 293 57  0   4  140      241  0   0       123     1     0.2     2     0.0 7.0
# 294 45  1   1  110      264  0   0       132     0     1.2     2     0.0 7.0
# 295 68  1   4  144      193  1   0       141     0     3.4     2     2.0 7.0
# 296 57  1   4  130      131  0   0       115     1     1.2     2     1.0 7.0
# 297 57  0   2  130      236  0   2       174     0     0       2     1.0 3.0
# 298 56  1   4  120      100  0   0       120     1     1.5     2     0   7
# 299 47  1   4  150      226  0   0       98      1     1.5     2     0   7
#     num
# 1   0
# 2   2
# 3   1
# 4   0
# 5   0
# 6   0
# 7   3
# 8   0
# 9   2
# 10  1
# 11  0
# 12  0
# 13  2
# 14  0
# 15  0
# 16  0
# 17  1
# 18  0
# 19  0
# 20  0
# 21  0
# 22  0
# 23  1
# 24  3
# 25  4
# 26  0
# 27  0
# 28  0
# 29  0
# 30  3
# ⋮   ⋮
# 270 0
# 271 1
# 272 0
# 273 0
# 274 0
# 275 1
# 276 0
# 277 2
# 278 0
# 279 3
# 280 0
# 281 2
# 282 4
# 283 2
# 284 0
# 285 0
# 286 1
# 287 0
# 288 2
# 289 2
# 290 1
# 291 0
# 292 3
# 293 1
# 294 1
# 295 2
# 296 3
# 297 1
# 298 1
# 299 1
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
